# %%
from flask import Flask, request, jsonify
import pandas as pd
import numpy as np
import fraud_utils
from fraud_utils import *
import joblib 
from joblib import *
import ml_explainability_utils
from ml_explainability_utils import *
X_train_ad, y_train_ad, X_train_smote, y_train_smote, X_train_stomek, y_train_stomek = get_data()

# %%
rfc_pipeline = joblib.load('rfc_smote_pipeline.pkl')
gbc_pipeline = joblib.load('gbc_smote_pipeline.pkl')
mlp_pipeline = joblib.load('mlp_smotetomek_pipeline.pkl')


User_id = 'C3562'
transaction_type = 1
amount = 3698899.0
step = 600
oldbalanceOrg = 262975.8




newbalanceOrig = oldbalanceOrg + amount
# Create DataFrame with a dictionary


    
df = pd.DataFrame({'step': [step], 'type': [transaction_type], 'amount': [amount], 
                   'oldbalanceOrg': [oldbalanceOrg], 'newbalanceOrig': [newbalanceOrig]})

live_df = generate_transaction_features(df)

live_df
# Out:
#    step  type     amount  oldbalanceOrg    bal_chg  orig_zero  amt_bal_ratio  \
# 0   600     1  3698899.0       262975.8  3698899.0          0      14.065549
#
#    chg_amt_ratio
# 0            1.0

# %%
# Selecting the first instance from the live data
pipeline = rfc_pipeline

# Make a prediction using the trained pipeline
prediction = pipeline.predict(live_df)[0]
prediction
# Out:
# 0

# %%
X_train =  X_train_smote    #X_train_smote  
live_instance = live_df  
model_name = 'Random Forest'

# %%
interpreter = LIMEModelInterpreter(pipeline, X_train, live_instance, model_name)
lime_explanation, prediction = interpreter.limeExplainer_live()
feature_explanations = interpreter.lime_feature_extraction(lime_explanation)
interpreter.interpret_lime_results(feature_explanations, prediction)
explanations_plot = interpreter.plot_lime_explanation(feature_explanations)
explanations = interpreter.calculate_and_print_feature_influence(feature_explanations)
explanations_plot.show()
print(explanations)
# Out:
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning:
#
# X does not have valid feature names, but StandardScaler was fitted with feature names
# Intercept 0.08337125786252353
# Prediction_local [0.65790123]
# Right: 0.87
# <div>                            <div id="d69a6e25-e216-4daa-b4fd-33db05c1c09e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d69a6e25-e216-4daa-b4fd-33db05c1c09e")) {                    Plotly.newPlot(                        "d69a6e25-e216-4daa-b4fd-33db05c1c09e",                        [{"alignmentgroup":"True","hovertemplate":"Importances=%{x}<br>Feature_Names=%{y}<extra></extra>","legendgroup":"","marker":{"color":["blue","blue","orange","orange","orange","orange","orange","orange"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[-0.06112194958100168,0.0,0.02424805287709268,0.027761772214862545,0.07861836298293894,0.0808262059763437,0.21209876588908197,0.212098765889082],"xaxis":"x","y":["amt_bal_ratio","type","step","orig_zero","oldbalanceOrg","amount","chg_amt_ratio","bal_chg"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"lin ...
# bal_chg pushed this prediction outcome towards Fraudulent Class by 30.4%
# chg_amt_ratio pushed this prediction outcome towards Fraudulent Class by 30.4%
# amount pushed this prediction outcome towards Fraudulent Class by 11.6%
# oldbalanceOrg pushed this prediction outcome towards Fraudulent Class by 11.3%
# amt_bal_ratio pushed this prediction outcome away from Fraudulent to Legitimate Class by -8.8%
# orig_zero pushed this prediction outcome towards Fraudulent Class by 4.0%
# step pushed this prediction outcome towards Fraudulent Class by 3.5%
# type pushed this prediction outcome towards Fraudulent Class by 0.0%

# %%
visualizer = SHAPVisualizer(pipeline, live_instance, X_train)

visualizer_plot = visualizer.shap_exp_plot()
influence_shap = visualizer.shap_feature_influence()
shap_percentage = visualizer.shap_feature_influence_percentage()
print(shap_percentage)
visualizer_plot.show()
print(influence_shap)
# Out:
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning:
#
# X does not have valid feature names, but StandardScaler was fitted with feature names
#   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning:
#
# X does not have valid feature names, but StandardScaler was fitted with feature names
#   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning:
#
# X does not have valid feature names, but StandardScaler was fitted with feature names
#   0%|          | 0/1 [00:00<?, ?it/s]
# Percentage of features that increase likelihood of being classified as 'Fraudulent': 62.50%
# Percentage of features that increase likelihood of being classified as 'Legitimate': 25.00%
# Percentage of features with no effect on the classification: 12.50%
# <div>                            <div id="774e2cd5-d439-4688-ae32-65934a2c1d74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("774e2cd5-d439-4688-ae32-65934a2c1d74")) {                    Plotly.newPlot(                        "774e2cd5-d439-4688-ae32-65934a2c1d74",                        [{"marker":{"color":["blue","blue","red","red","red","red","red","red"]},"orientation":"h","x":[-0.22366666666666646,-0.021333333333333204,0.0,0.040833333333333166,0.06216666666666648,0.06866666666666671,0.09933333333333355,0.46399999999999975],"y":["amt_bal_ratio","chg_amt_ratio","type","orig_zero","bal_chg","step","amount","oldbalanceOrg"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","mar ...
# oldbalanceOrg pushed this prediction outcome towards Fraudulent Class by 47.3%
# amount pushed this prediction outcome towards Fraudulent Class by 10.1%
# step pushed this prediction outcome towards Fraudulent Class by 7.0%
# bal_chg pushed this prediction outcome towards Fraudulent Class by 6.3%
# orig_zero pushed this prediction outcome towards Fraudulent Class by 4.2%
# type pushed this prediction outcome towards Fraudulent Class by 0.0%
# chg_amt_ratio pushed this prediction outcome away from Fraudulent to Legitimate Class by -2.2%
# amt_bal_ratio pushed this prediction outcome away from Fraudulent to Legitimate Class by -22.8%

# %%
# Selected_model == "Random Forest"
# # Create an instance of ModelExplainer
# explainer = ModelExplainer(pipeline, live_df)

# print(" ")

# #explainer.shap_interactions()

# explainer.create_network_graph_with_communities()
# networkx_exp()
# top_main_effect, top_interaction = explainer.features_interaction()
# # print(top_main_effect)
# # print(top_interaction)

explainer = ModelExplainer(pipeline, live_df)

interaction_data_long = explainer.prepare_interaction_data_for_graph()
# Out:
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:432: UserWarning:
#
# X has feature names, but RandomForestClassifier was fitted without feature names

# %%
y_train = y_train_smote

cf_as_dict, original_instance = cf_explanations(pipeline, X_train, y_train, live_instance, model_name, total_CFs=1)
narrative = explain_counterfactual_percentage(original_instance, cf_as_dict)
print(narrative)

# %%
# pipeline = gbc_pipeline
# Selected_model == "Gradient Boost"
# explainer = ModelExplainer(pipeline, live_df)
# #interaction_df = explainer.shap_interactions_gbc()

# explainer.create_network_graph_with_communities_gbc()
# networkx_exp()
# top_main_effect, top_interaction = explainer.features_interaction_gbc()
# # print("")
# # print(top_main_effect)
# # print("")
# # print(top_interaction)

# %%
#explainer = ModelExplainer(pipeline, live_df)

def analyze_model_interactions(model_name, technique_name, explainer):
    # Initialize return variables to None as default
    netwgraph_plot, ax, network_explainer, top_main_effect, top_interaction = None, None, None, None, None
    
    if model_name in ["Random Forest", "Gradient Boost"] and technique_name == "SHAP":
        
        if model_name == "Random Forest":
            netwkgraph_plot, ax = explainer.create_network_graph_with_communities()
            network_explainer = networkx_exp()  
            top_main_effect, top_interaction = explainer.features_interaction()
        elif model_name == "Gradient Boost":
            netwkgraph_plot, ax = explainer.create_network_graph_with_communities_gbc()
            network_explainer = networkx_exp()
            top_main_effect, top_interaction = explainer.features_interaction_gbc()
    else:
        print(f"For Feature Interactions, Use Random Forest/Gradient Boost Model.")
        return None, None, None, None, None  

    return netwkgraph_plot, ax, network_explainer, top_main_effect, top_interaction

# %%
def analyze_model_interactions1(model_name, technique_name, explainer):
    # Initialize return variables to None as default
    netwgraph_plot, ax, network_explainer, top_main_effect, top_interaction = None, None, None, None  # Corrected to 4 variables
    
    if model_name in ["Random Forest", "Gradient Boost"] and technique_name == "SHAP":
        
        if model_name == "Random Forest":
            netwgraph_plot, ax = explainer.create_network_graph_with_communities()
            network_explainer = networkx_exp()  
            top_main_effect, top_interaction = explainer.features_interaction()
        elif model_name == "Gradient Boost":
            netwgraph_plot = explainer.create_network_graph_with_communities_gbc()
            network_explainer = networkx_exp()
            top_main_effect, top_interaction = explainer.features_interaction_gbc()
    else:
        print(f"For Feature Interactions, Use Random Forest/Gradient Boost Model.")
        return None, None, None, None  

    return netwgraph_plot, ax, network_explainer, top_main_effect, top_interaction

# %%
import matplotlib.pyplot as plt
pipeline = rfc_pipeline
X_train =  X_train_smote    #X_train_smote  
live_df = live_df  
model_name = 'Random Forest'
technique_name = 'SHAP'

explainer = ModelExplainer(pipeline, live_df)
netwkgraph_plot, ax,  network_explainer, top_main_effect, top_interaction = analyze_model_interactions(model_name, technique_name, explainer)

netwkgraph_plot.show()
# print(network_explainer)

# print(top_main_effect)
# print(top_interaction)
interaction_data_long = explainer.prepare_interaction_data_for_graph()
interaction_data_long_gbc = explainer.prepare_interaction_data_for_graph_gbc()

G = nx.Graph()
for _, row in interaction_data_long.iterrows():
    G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

partition = community_louvain.best_partition(G)
pos = nx.spring_layout(G)

community_cmap = cm.coolwarm
community_colors = [community_cmap(i / max(partition.values())) for i in partition.values()]

fig, ax = plt.subplots(figsize=(11, 8))
nx.draw_networkx_nodes(G, pos, ax=ax, node_color=community_colors, node_size=500)

print(partition)
fig = create_network_graph_updated_1(interaction_data_long)
fig.show()
# Out:
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:432: UserWarning:
#
# X has feature names, but RandomForestClassifier was fitted without feature names
#
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:432: UserWarning:
#
# X has feature names, but RandomForestClassifier was fitted without feature names
#
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6456\1928445662.py:11: UserWarning:
#
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:432: UserWarning:
#
# X has feature names, but RandomForestClassifier was fitted without feature names
#
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:432: UserWarning:
#
# X has feature names, but RandomForestClassifier was fitted without feature names
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[352], line 17
#      12 # print(network_explainer)
#      13
#      14 # print(top_main_effect)
#      15 # print(top_interaction)
#      16 interaction_data_long = explainer.prepare_interaction_data_for_graph()
# ---> 17 interaction_data_long_gbc = explainer.prepare_interaction_data_for_graph_gbc()
#      19 G = nx.Graph()
#      20 for _, row in interaction_data_long.iterrows():
#
# File ~\Desktop\FraudSenseXAI - Copy\ml_explainability_utils.py:300, in ModelExplainer.prepare_interaction_data_for_graph_gbc(self)
#     299 def prepare_interaction_data_for_graph_gbc(self):
# --> 300     interaction_df = self.shap_interactions_gbc()
#     301     # Use only the lower triangle of the interaction matrix, as it is symmetric
#     302     lower_triangle_mask = np.tril(np.ones(interaction_df.shape)).astype(bool)
#
# File ~\Desktop\FraudSenseXAI - Copy\ml_explainability_utils.py:271, in ModelExplainer.shap_interactions_gbc(self)
#     269 shap_interaction_values = explainer.shap_interaction_values(df_live.iloc[0])
#     270 predicted_class = model.predict(df_live)[0]
# --> 271 if shap_interaction_values.ndim == 3:
#     272     interaction_values = shap_interaction_values[predicted_class]
#     273 elif shap_interaction_values.ndim == 2:
#
# AttributeError: 'list' object has no attribute 'ndim'

# %%
def choose_model_interpretability(technique_name, interpreter, visualizer, feature_explanations, prediction):
    if technique_name == 'LIME':
        mod_explanation = interpreter.interpret_lime_results(feature_explanations, prediction)
        mod_plot = interpreter.plot_lime_explanation(feature_explanations)
        features_influence = interpreter.calculate_and_print_feature_influence(feature_explanations)
    elif technique_name == 'SHAP':
        mod_explanation = visualizer.shap_feature_influence_percentage()
        mod_plot = visualizer.shap_exp_plot()
        features_influence = visualizer.shap_feature_influence()
    else:
        raise ValueError("Invalid technique_name")
    return  mod_explanation,  mod_plot, features_influence

# %%
explainer = ModelExplainer(pipeline, live_df)
interpreter = LIMEModelInterpreter(pipeline, X_train, live_instance, model_name)
lime_explanation, prediction = interpreter.limeExplainer_live()
feature_explanations = interpreter.lime_feature_extraction(lime_explanation)
visualizer = SHAPVisualizer(pipeline, live_instance, X_train)
mod_explaination,  mod_plot, features_influence = choose_model_interpretability(technique_name, interpreter, visualizer, feature_explanations, prediction)
netwkgraph_plot, network_explainer, top_main_effect, top_interaction = analyze_model_interactions(model_name, technique_name, explainer)
# Out:
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning:
#
# X does not have valid feature names, but StandardScaler was fitted with feature names
# Intercept 0.08953491962147364
# Prediction_local [0.57402328]
# Right: 0.76
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning:
#
# X does not have valid feature names, but StandardScaler was fitted with feature names
#   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning:
#
# X does not have valid feature names, but StandardScaler was fitted with feature names
#   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning:
#
# X does not have valid feature names, but StandardScaler was fitted with feature names
#   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:432: UserWarning:
#
# X has feature names, but RandomForestClassifier was fitted without feature names
#
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:432: UserWarning:
#
# X has feature names, but RandomForestClassifier was fitted without feature names

# %%
pipeline = rfc_pipeline
X_train =  X_train_smote   #X_train_smote  
live_df = live_df 
live_instance = live_df 
model_name = 'Random Forest'
technique_name = 'LIME'



interpreter = LIMEModelInterpreter(pipeline, X_train, live_instance, model_name)
lime_explanation, prediction = interpreter.limeExplainer_live()
feature_explanations = interpreter.lime_feature_extraction(lime_explanation)
visualizer = SHAPVisualizer(pipeline, live_instance, X_train)

mod_explaination,  mod_plot, features_influence =choose_model_interpretability(technique_name, interpreter, visualizer, feature_explanations, prediction)

print(mod_explaination)
mod_plot.show()
print(f'\n{features_influence}')
# Out:
# Intercept 0.09156950083717384
# Prediction_local [0.57372444]
# Right: 0.76
# The model's prediction likelihood of being classified as Fraudulent increases because 'chg_amt_ratio' is more than 0.00.
# The model's prediction likelihood of being classified as Fraudulent increases because 'bal_chg' is more than 0.00.
# The model's prediction likelihood of being classified as Fraudulent increases because 'amount' is more than 205538.95.
# The model's prediction likelihood of being classified as Legitimate increases because 'amt_bal_ratio' is not more than 0.21.
# The model's prediction likelihood of being classified as Fraudulent increases because 'oldbalanceOrg' is more than 51233.06.
# The model's prediction likelihood of being classified as Fraudulent increases because 'orig_zero' is not more than 0.00.
# The model's prediction likelihood of being classified as Legitimate increases because '304.00<step' is not more than 406.00.
#
# Percentage of features that increase likelihood of 'Fraudulent': 71.43%
# Percentage of features that increase likelihood of 'Legitimate': 28.57%
# Percentage of features with no effect: 12.50%
# Features with no effect on the prediction: type=1
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning:
#
# X does not have valid feature names, but StandardScaler was fitted with feature names
# <div>                            <div id="d7133f22-7a39-4130-ab76-0a1d02548454" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7133f22-7a39-4130-ab76-0a1d02548454")) {                    Plotly.newPlot(                        "d7133f22-7a39-4130-ab76-0a1d02548454",                        [{"alignmentgroup":"True","hovertemplate":"Importances=%{x}<br>Feature_Names=%{y}<extra></extra>","legendgroup":"","marker":{"color":["blue","blue","blue","orange","orange","orange","orange","orange"],"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[-0.06777292409542865,-0.0012475269110686805,0.0,0.03436849940170626,0.064600070167161,0.07965570713685657,0.18627555782120153,0.1862755578212016],"xaxis":"x","y":["amt_bal_ratio","step","type","orig_zero","oldbalanceOrg","amount","bal_chg","chg_amt_ratio"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"lin ...
# chg_amt_ratio pushed this prediction outcome towards Fraudulent Class by 30.0%
# bal_chg pushed this prediction outcome towards Fraudulent Class by 30.0%
# amount pushed this prediction outcome towards Fraudulent Class by 12.8%
# amt_bal_ratio pushed this prediction outcome away from Fraudulent to Legitimate Class by -10.9%
# oldbalanceOrg pushed this prediction outcome towards Fraudulent Class by 10.4%
# orig_zero pushed this prediction outcome towards Fraudulent Class by 5.5%
# step pushed this prediction outcome away from Fraudulent to Legitimate Class by -0.2%
# type pushed this prediction outcome towards Fraudulent Class by 0.0%

# %%
#explainer = ModelExplainer(pipeline, live_df)

def analyze_model_interactions(model_name, technique_name, explainer):
    # Initialize return variables to None as default
    netwgraph_plot, ax, network_explainer, top_main_effect, top_interaction = None, None, None, None, None
    
    if model_name in ["Random Forest", "Gradient Boost"] and technique_name == "SHAP":
        
        if model_name == "Random Forest":
            netwkgraph_plot, ax = explainer.create_network_graph_with_communities()
            network_explainer = networkx_exp()  
            top_main_effect, top_interaction = explainer.features_interaction()
        elif model_name == "Gradient Boost":
            netwkgraph_plot, ax = explainer.create_network_graph_with_communities_gbc()
            network_explainer = networkx_exp()
            top_main_effect, top_interaction = explainer.features_interaction_gbc()
    else:
        print(f"For Feature Interactions, Use Random Forest/Gradient Boost Model.")
        return None, None, None, None, None  

    return netwkgraph_plot, ax, network_explainer, top_main_effect, top_interaction

# %%
import matplotlib.pyplot as plt
pipeline = rfc_pipeline
X_train =  X_train_smote    #X_train_smote  
live_df = live_df  
model_name = 'Random Forest'
technique_name = 'SHAP'

explainer = ModelExplainer(pipeline, live_df)
netwkgraph_plot, ax, network_explainer, top_main_effect, top_interaction = analyze_model_interactions(model_name, technique_name, explainer)

netwkgraph_plot
plt.show()
print(network_explainer)

print(top_main_effect)
print(top_interaction)
# Out:
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:432: UserWarning:
#
# X has feature names, but RandomForestClassifier was fitted without feature names
#
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:432: UserWarning:
#
# X has feature names, but RandomForestClassifier was fitted without feature names
# The size and color of each feature's cluster ring represent its contribution to the prediction outcome.
# Larger and more intensely colored rings indicate a stronger contribution.
#
# The size and color of each linkage between nodes represent the strength of interactions between those nodes.
# Thicker and more intensely colored linkages indicate stronger interactions.
#
# Top 3 Features with Strongest Impact:
# amt_bal_ratio    0.380562
# chg_amt_ratio    0.215940
# oldbalanceOrg    0.075649
# dtype: float64
#
# Top 4 Feature Interactions:
# chg_amt_ratio  amt_bal_ratio    0.100549
# amt_bal_ratio  chg_amt_ratio    0.100549
# oldbalanceOrg  chg_amt_ratio    0.067069
# chg_amt_ratio  oldbalanceOrg    0.067069
# dtype: float64

# %%
import matplotlib.pyplot as plt
pipeline = rfc_pipeline
X_train =  X_train_smote    #X_train_smote  
live_df = live_df  
model_name = 'Random Forest'
technique_name = 'SHAP'

explainer = ModelExplainer(pipeline, live_df)
explainer.prepare_interaction_data_for_graph().head(2)

# %%
explainer.prepare_interaction_data_for_graph().head(2)
# Out:
# X has feature names, but RandomForestClassifier was fitted without feature names
#   Feature1 Feature2  Interaction
# 0     step     step    -0.027289
# 3   amount     step    -0.000304

# %%
import pandas as pd
import networkx as nx
from community import community_louvain
import numpy as np
from pyvis.network import Network
import matplotlib.cm as cm

def create_network_graph_with_communities(interaction_data_long):
    # Prepare interaction data
#     interaction_data_long = self.prepare_interaction_data_for_graph()

    # Create a networkx graph
    G = nx.Graph()
    for _, row in interaction_data_long.iterrows():
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    # Detect communities
    partition = community_louvain.best_partition(G)

    # Initialize PyVis network object
    net = Network(height="750px", width="100%", bgcolor="#222222", font_color="white")
    net.barnes_hut()

    # Generate a color palette for communities
    community_ids = set(partition.values())
    community_colors = [cm.coolwarm(i / max(community_ids)) for i in community_ids]

    # Add nodes with community color
    for node, community_id in partition.items():
        net.add_node(node, title=node, color=np.array(community_colors[community_id])[:3] * 255, group=community_id)

    # Add edges
    for edge in G.edges(data=True):
        src, dst, w = edge
        net.add_edge(src, dst, value=w['weight'])

    # Enable physics and interaction controls
    net.show_buttons(filter_=['physics'])

    # Save and show the network
    net.show("network_with_communities.html")

# %%
# !pip uninstall pyvis -y
# !pip install pyvis

# %%
interaction_data_long = explainer.prepare_interaction_data_for_graph()
interaction_data_long.head()
# Out:
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:432: UserWarning:
#
# X has feature names, but RandomForestClassifier was fitted without feature names
#         Feature1 Feature2  Interaction
# 0           step     step    -0.027289
# 3         amount     step    -0.000304
# 5         amount   amount    -0.047766
# 6  oldbalanceOrg     step     0.002877
# 8  oldbalanceOrg   amount     0.042320

# %%
import pandas as pd
import networkx as nx
from community import community_louvain
import numpy as np
from pyvis.network import Network
import matplotlib.cm as cm

class NetworkGraphWithCommunities:
    def prepare_interaction_data_for_graph(self):
        # This is a placeholder for your actual data preparation method.
        # It should return a pandas DataFrame with columns ['Feature1', 'Feature2', 'Interaction']
        # Here's a dummy example of what such a DataFrame might look like:
        data = {
            'Feature1': ['A', 'B', 'C', 'A'],
            'Feature2': ['B', 'C', 'D', 'C'],
            'Interaction': [1, 2, 3, 4]
        }
        return pd.DataFrame(data)

    def create_network_graph_with_communities(self):
        # Prepare interaction data
        interaction_data_long = self.prepare_interaction_data_for_graph()

        # Create a networkx graph
        G = nx.Graph()
        for _, row in interaction_data_long.iterrows():
            G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

        # Detect communities
        partition = community_louvain.best_partition(G)

        # Initialize PyVis network object
        net = Network(height="750px", width="100%", bgcolor="#222222", font_color="white")
        net.barnes_hut()

        # Generate a color palette for communities
        community_ids = set(partition.values())
        community_colors = [cm.coolwarm(i / max(community_ids)) for i in community_ids]

        # Add nodes with community color
        for node, community_id in partition.items():
            net.add_node(node, title=node, color=np.array(community_colors[community_id])[:3] * 255, group=community_id)

        # Add edges
        for edge in G.edges(data=True):
            src, dst, w = edge
            net.add_edge(src, dst, value=w['weight'])

        # Enable physics and interaction controls
        net.show_buttons(filter_=['physics'])

        # Save and show the network
        net.show("network_with_communities.html")

# Usage
if __name__ == "__main__":
    graph_creator = NetworkGraphWithCommunities()
    graph_creator.create_network_graph_with_communities()

# %%
# !pip install pyvis

# %%
    def create_network_graph_with_communities(self):
        interaction_data_long = self.prepare_interaction_data_for_graph()

        G = nx.Graph()
        for _, row in interaction_data_long.iterrows():
            G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

        partition = community_louvain.best_partition(G)
        pos = nx.spring_layout(G)

        community_cmap = cm.coolwarm
        community_colors = [community_cmap(i / max(partition.values())) for i in partition.values()]

        fig, ax = plt.subplots(figsize=(11, 8))
        nx.draw_networkx_nodes(G, pos, ax=ax, node_color=community_colors, node_size=500)

        edges = G.edges(data=True)
        weights = [edata['weight'] for _, _, edata in edges]
        # Calculate the maximum weight for normalizing edge widths
        max_weight = max(weights) if weights else 1  # Avoid division by zero if weights list is empty

        edge_norm = colors.Normalize(vmin=min(weights), vmax=max(weights))
        edge_cmap = cm.plasma
        # Adjust the calculation for edge width based on max_weight
        for (u, v, edata), width in zip(edges, [edata['weight'] / max_weight * 10 for _, _, edata in edges]):
            edge_color = edge_cmap(edge_norm(edata['weight']))
            nx.draw_networkx_edges(G, pos, edgelist=[(u, v)], width=width, ax=ax, edge_color=edge_color, alpha=0.7)

        for node, (x, y) in pos.items():
            text = ax.text(x, y, node, ha='center', va='center', fontdict={'color': 'black', 'size': 8})
            text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

        sm = cm.ScalarMappable(cmap=edge_cmap, norm=edge_norm)
        sm.set_array([])
        cbar = fig.colorbar(sm, ax=ax, shrink=0.5, aspect=10)
        cbar.set_label('Interaction Strength')

        community_legend = [plt.Line2D([0], [0], marker='o', color='w', label=f"Community {i+1}",
                                       markerfacecolor=community_cmap(i / max(partition.values())), markersize=15)
                            for i in range(max(partition.values()) + 1)]
        ax.legend(handles=community_legend, title='Communities', loc='upper left', bbox_to_anchor=(1, 1.1))

        ax.set_title("Feature Interactions with Community Detection - Network Graph")
        plt.axis('off')

        return fig, ax

# %%
import plotly.graph_objs as go
import pandas as pd
import networkx as nx
from community import community_louvain
import matplotlib.cm as cm
import matplotlib.colors as mcolors


def create_network_graph_with_communities3(interaction_data_long):

    # Create graph
    G = nx.Graph()
    for _, row in interaction_data_long.iterrows():
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    # Community detection
    partition = community_louvain.best_partition(G)
    pos = nx.spring_layout(G)

    # Node colors based on the community
    community_ids = list(set(partition.values()))
    community_cmap = cm.get_cmap('coolwarm', len(community_ids))

    # Normalize community ids to [0, 1] for color mapping
    norm = mcolors.Normalize(vmin=min(community_ids), vmax=max(community_ids))
    node_color_map = [community_cmap(norm(partition[node])) for node in G.nodes()]

    # Edge traces
    edge_trace = []
    for edge in G.edges(data=True):
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        weight = edge[2]['weight']
        edge_trace.append(go.Scatter(
            x=[x0, x1, None],
            y=[y0, y1, None],
            line=dict(width=weight * 10, color='Lightgrey'),
            hoverinfo='none',
            mode='lines'))

    # Node traces
    node_trace = go.Scatter(
        x=[],
        y=[],
        text=[],
        mode='markers+text',
        hoverinfo='text',
        textposition="bottom center",
        marker=dict(
            size=10,
            color=node_color_map,  # Use RGB colors from colormap
            line_width=2))

    for node in pos:
        x, y = pos[node]
        node_trace['x'] += tuple([x])
        node_trace['y'] += tuple([y])
        node_trace['text'] += tuple([node])

    # Create figure
    fig = go.Figure(data=edge_trace + [node_trace],
                    layout=go.Layout(
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=0, l=0, r=0, t=40),
                        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        height=600
                        ))

    # Add community legend (This is a placeholder, needs to be adjusted for your actual communities)
    for i, community_id in enumerate(community_ids):
        fig.add_trace(go.Scatter(
            x=[None],
            y=[None],
            mode='markers',
            marker=dict(size=10, color=community_cmap(norm(community_id))),
            legendgroup='Community',
            showlegend=True,
            name=f'Community {community_id+1}'
        ))

    fig.show()

# %%
import plotly.graph_objs as go
import networkx as nx
from community import community_louvain
import matplotlib.cm as cm
import matplotlib.colors as mcolors

def create_network_graph_with_communities5(interaction_data_long):
    # Create graph
    G = nx.Graph()
    for _, row in interaction_data_long.iterrows():
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    # Community detection
    partition = community_louvain.best_partition(G)
    pos = nx.spring_layout(G)

    # Normalize the node sizes and colors
    node_size = [G.degree(node) * 10 for node in G.nodes()]
    node_color = [float(G.degree(node)) for node in G.nodes()]

    # Normalize the edge weights
    weights = [edata['weight'] for u, v, edata in G.edges(data=True)]
    edge_width = [edata['weight'] / max(weights) * 10 for u, v, edata in G.edges(data=True)]

    edge_trace = go.Scatter(
        x=[],
        y=[],
        line=dict(width=edge_width),
        hoverinfo='none',
        mode='lines')

    for edge in G.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_trace['x'] += tuple([x0, x1, None])
        edge_trace['y'] += tuple([y0, y1, None])

    node_trace = go.Scatter(
        x=[],
        y=[],
        text=[],
        mode='markers+text',
        hoverinfo='text',
        marker=dict(
            showscale=True,
            colorscale='YlGnBu',
            reversescale=True,
            color=node_color,
            size=node_size,
            colorbar=dict(
                thickness=15,
                title='Node Connections',
                xanchor='left',
                titleside='right'
            ),
            line_width=2))

    for node in G.nodes():
        x, y = pos[node]
        node_trace['x'] += tuple([x])
        node_trace['y'] += tuple([y])
        node_trace['text'] += tuple([node])

    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(
                        showlegend=False,
                        hovermode='closest',
                        margin=dict(b=0, l=0, r=0, t=0),
                        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        height=600
                    ))

    fig.update_layout(title_text='Network graph with community detection')
    fig.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import patheffects
import networkx as nx
from community import community_louvain
import matplotlib.cm as cm
import matplotlib.colors as colors

class GraphVisualization:
    def prepare_interaction_data_for_graph(self):
        # This method should return a DataFrame with your interaction data
        # For example, it might look something like this:
        # return pd.DataFrame({
        #     'Feature1': ['A', 'B', 'C', 'D'],
        #     'Feature2': ['B', 'C', 'D', 'A'],
        #     'Interaction': [0.1, 0.2, 0.3, 0.4]
        # })
        pass

    def create_network_graph_with_communities(self):
        interaction_data_long = self.prepare_interaction_data_for_graph()

        # Create a graph
        G = nx.Graph()

        # Add edges to the graph with weights
        for _, row in interaction_data_long.iterrows():
            G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

        # Compute the best partition (community detection)
        partition = community_louvain.best_partition(G)
        pos = nx.spring_layout(G)  # positions for all nodes

        # Create a color map based on communities using coolwarm
        community_cmap = cm.coolwarm
        community_colors = [community_cmap(i / max(partition.values())) for i in partition.values()]

        # Set up figure and axes
        fig, ax = plt.subplots(figsize=(11, 8))

        # Drawing nodes with community color
        nx.draw_networkx_nodes(G, pos, ax=ax, node_color=community_colors, node_size=500)

        # Drawing edges with varying thickness and color based on weights
        edges = G.edges(data=True)
        weights = [edata['weight'] for _, _, edata in edges]
        max_weight = max(weights)
        edge_norm = colors.Normalize(vmin=min(weights), vmax=max(weights))
        edge_cmap = cm.plasma  # Using a different colormap for edge strengths
        for (u, v, edata), width in zip(edges, [edata['weight'] / max_weight * 10 for _, _, edata in edges]):
            edge_color = edge_cmap(edge_norm(edata['weight']))
            nx.draw_networkx_edges(G, pos, edgelist=[(u, v)], width=width, ax=ax, edge_color=edge_color, alpha=0.7)

        # Draw node labels with halo effect for better visibility
        for node, (x, y) in pos.items():
            text = ax.text(x, y, node, horizontalalignment='center', verticalalignment='center',
                           fontdict={'color': 'black', 'size': 8})
            text.set_path_effects([
                patheffects.withStroke(linewidth=3, foreground='white')
            ])

        # Add color bar for edges to act as legend for interaction strengths
        sm = cm.ScalarMappable(cmap=edge_cmap, norm=edge_norm)
        sm.set_array([])
        cbar = fig.colorbar(sm, ax=ax, shrink=0.5, aspect=10)
        cbar.set_label('Interaction Strength')

        # Add legend for communities
        community_legend = [plt.Line2D([0], [0], marker='o', color='w', label=f"Community {i+1}",
                                       markerfacecolor=community_cmap(i / max(partition.values())), markersize=15)
                            for i in range(max(partition.values()) + 1)]
        ax.legend(handles=community_legend, title='Communities', loc='upper left', bbox_to_anchor=(1, 1.1), borderaxespad=0.)

        ax.set_title("Network Graph of Feature Interactions with Community Detection")
        plt.axis('off')

        # Save the figure to an image file
        plt.savefig('network_graph.png', format='png', bbox_inches='tight')
        plt.close()  # Close the figure to release memory

        return 'network_graph.png'

# This would be used in your Gradio interface
def plot_networkx_graph():
    visualizer = GraphVisualization()
    image_path = visualizer.create_network_graph_with_communities()
    return image_path

# Assuming the rest of your Gradio interface setup is the same as before

# %%
def plot_networkx_graph(model_name, technique_name, explainer):
    
    image_path = None
    if model_name in ["Random Forest", "Gradient Boost"] and technique_name == "SHAP":

        if model_name == "Random Forest":

    image_path = explainer.create_network_graph_with_communities_v1()

        elif model_name == "Gradient Boost":
    image_path = explainer.create_network_graph_with_communities_gbc_v1()
    
    else:
        print(f"Network Graph Not Available.")
        return None
    
    return send_file(image_path, mimetype='image/png')

# %%
import networkx as nx
from community import community_louvain
import plotly.graph_objects as go
import numpy as np

def create_network_graph_with_communities_v1_plotly2(interaction_data_long):
    # Create a graph
    G = nx.Graph()

    # Assuming 'interaction_data_long' is a DataFrame with 'Feature1', 'Feature2', 'Interaction'
    for _, row in interaction_data_long.iterrows():
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    # Community detection
    partition = community_louvain.best_partition(G)
    
    # Position nodes using the spring layout
    pos = nx.spring_layout(G, seed=42)  # For consistent layout between runs

    node_x = []
    node_y = []
    node_color = []
    text = []

    # Map partition values to a continuous range of colors
    unique_communities = np.unique(list(partition.values()))
    colors = np.linspace(0, 1, len(unique_communities))
    community_color_map = dict(zip(unique_communities, colors))

    for node in G.nodes():
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        node_color.append(community_color_map[partition[node]])
        text.append(node)

    edge_x = []
    edge_y = []
    for edge in G.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])

    edge_trace = go.Scatter(x=edge_x, y=edge_y, line=dict(width=0.5, color='#888'), hoverinfo='none', mode='lines')
    node_trace = go.Scatter(x=node_x, y=node_y, mode='markers+text', hoverinfo='text', text=text,
                            marker=dict(color=node_color, size=10, colorscale='Viridis', colorbar=dict(title='Community')))

    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(showlegend=False, hovermode='closest',
                                     margin=dict(b=0,l=0,r=0,t=0),
                                     xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                                     yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

    return fig

# %%
fig = create_network_graph_with_communities_v1_plotly2(interaction_data_long)
fig.show()
# Out:
# <div>                            <div id="a072162c-696f-4363-a67c-09f3f9e0f22c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
# %%
import networkx as nx
from community import community_louvain
import plotly.graph_objects as go
import matplotlib.pyplot as plt

def create_network_graph_with_communities_v1_plotly3(interaction_data_long):
    # Create a graph
    G = nx.Graph()

    # Assuming 'interaction_data_long' is a DataFrame with 'Feature1', 'Feature2', 'Interaction'
    for _, row in interaction_data_long.iterrows():
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    # Community detection
    partition = community_louvain.best_partition(G)
    pos = nx.spring_layout(G, seed=42)  # For consistent layout between runs

    # Extracting edge weights for visualization
    weights = [edata['weight'] for _, _, edata in G.edges(data=True)]
    max_weight = max(weights)
    edge_width = [edata['weight']/max_weight*5 for _, _, edata in G.edges(data=True)]  # Scale edge widths

    # Create edge trace
    edge_trace = []
    for edge, width in zip(G.edges(), edge_width):
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_trace.append(go.Scatter(x=[x0, x1, None], y=[y0, y1, None],
                                     line=dict(width=width, color='LightSkyBlue'),
                                     hoverinfo='none', mode='lines'))

    # Create node trace
    node_trace = go.Scatter(x=[], y=[], text=[], mode='markers', hoverinfo='text',
                            marker=dict(showscale=True, colorscale='YlGnBu', reversescale=True, color=[], size=[], 
                                        colorbar=dict(thickness=15, title='Node Connections', xanchor='left', titleside='right')))
    
    # Adding node position, size and community color to node_trace
    for node in G.nodes():
        x, y = pos[node]
        node_trace['x'] += tuple([x])
        node_trace['y'] += tuple([y])
        node_trace['marker']['color'] += tuple([len(G.edges(node))])  # Node color based on connections
        node_trace['text'] += tuple([node])
        node_trace['marker']['size'] += tuple([10 + 5 * partition[node]])  # Node size based on community

    # Create figure
    fig = go.Figure(data=edge_trace + [node_trace],
                    layout=go.Layout(showlegend=False, hovermode='closest',
                                     margin=dict(b=0, l=0, r=0, t=0),
                                     xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                                     yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

    return fig

fig = create_network_graph_with_communities_v1_plotly3(interaction_data_long)
fig.show()
# Out:
# <div>                            <div id="516390bb-ada4-4eec-a9ad-5ef78f243027" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("516390bb-ada4-4eec-a9ad-5ef78f243027")) {                    Plotly.newPlot(                        "516390bb-ada4-4eec-a9ad-5ef78f243027",                        [{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":1.9451159260566135},"mode":"lines","x":[-0.9065246175495955,-0.9065246175495955,null],"y":[0.6570544198091492,0.6570544198091492,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":0.14348404754308142},"mode":"lines","x":[-0.9065246175495955,0.6679642485090955,null],"y":[0.6570544198091492,-0.67284585101305,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":0.2306229199676255},"mode":"lines","x":[-0.9065246175495955,-0.8160399797365304,null],"y":[0.6570544198091492,-0.4788677552950074,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":0.19958328605863798},"mode":"lines","x":[-0.9065246175495955,0.2673802679961401,null],"y":[0.6570544198091492,-0.011559610332036731,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":0.027416631596439242},"mode":"lines","x":[-0.9065246175495955,1.0,null],"y":[0.6570544198091492,0.7384546410569826,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":0.45642244298703116},"mode":"lines","x":[-0.9065246175495955,-0.18365298337293215,null],"y":[0.6570544198091492,0.41974197234941235,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":0.12659032773070356},"mode":"lines","x":[-0.9065246175495955,-0.029126935846177718,null],"y":[0.6570544198091492,-0.6519778165754504,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":1.2427051857187323},"mode":"lines","x":[0.6679642485090955,0.6679642485090955,null],"y":[-0.67284585101305,-0.67284585101305,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":0.06443080820522668},"mode":"lines","x":[0.6679642485090955,-0.8160399797365304,null],"y":[-0.67284585101305,-0.4788677552950074,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":0.40731186536357905},"mode":"lines","x":[0.6679642485090955,0.2673802679961401,null],"y":[-0.67284585101305,-0.011559610332036731,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":0.09348614845442824},"mode":"lines","x":[0.6679642485090955,1.0,null],"y":[-0.67284585101305,0.7384546410569826,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":0.2496943466311731},"mode":"lines","x":[0.6679642485090955,-0.18365298337293215,null],"y":[-0.67284585101305,0.41974197234941235,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":1.1184357637527853},"mode":"lines","x":[0.6679642485090955,-0.029126935846177718,null],"y":[-0.67284585101305,-0.6519778165754504,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":2.0115842884091557},"mode":"lines","x":[-0.8160399797365304,-0.8160399797365304,null],"y":[-0.4788677552950074,-0.4788677552950074,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":0.3374881747951763},"mode":"lines","x":[-0.8160399797365304,0.2673802679961401,null],"y":[-0.4788677552950074,-0.011559610332036731,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":0.08967208709605858},"mode":"lines","x":[-0.8160399797365304,1.0,null],"y":[-0.4788677552950074,0.7384546410569826,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"LightSkyBlue","width":0.24619040688543586},"mode":"lines","x":[-0.816039 ...

# %%
import networkx as nx
import plotly.graph_objects as go
from community import community_louvain
import matplotlib.cm as cm

def create_plotly_network_graph(interaction_data_long):
    # Create a graph
    G = nx.Graph()

    # Assuming interaction_data_long is a DataFrame with 'Feature1', 'Feature2', 'Interaction'
    for _, row in interaction_data_long.iterrows():
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    # Community detection
    partition = community_louvain.best_partition(G)
    pos = nx.spring_layout(G)

    # Edge traces
    edge_trace = []
    for edge in G.edges(data=True):
        char1, char2 = edge[0], edge[1]
        x0, y0 = pos[char1]
        x1, y1 = pos[char2]
        weight = edge[2]['weight']
        edge_trace.append(go.Scatter(
            x=[x0, x1, None], y=[y0, y1, None],
            line=dict(width=weight*5, color='rgba(75,75,75,1)'),
            hoverinfo='none',
            mode='lines'))

    # Node traces
    node_trace = go.Scatter(
        x=[], y=[], text=[], mode='markers+text', hoverinfo='text',
        marker=dict(showscale=True, color=[], size=[], colorscale='turbo'))

    # Adding node position, community color, and size (based on contribution)
    for node in G.nodes():
        node_trace['x'] += (pos[node][0],)
        node_trace['y'] += (pos[node][1],)
        node_trace['marker']['color'] += (partition[node],)
        node_trace['text'] += (node,)
        node_trace['marker']['size'] += (len(G[node])*10,)  # G[node] gives the adjacency dictionary
    

    # Create the figure
    fig = go.Figure(data=edge_trace + [node_trace],
                    layout=go.Layout(
                        showlegend=False, hovermode='closest',
                        margin=dict(b=0,l=0,r=0,t=0),
                        xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                        yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

    return fig

# %%
# Example usage:
# interaction_data_long = your_dataframe_here
fig = create_plotly_network_graph(interaction_data_long)
fig.show()
# Out:
# <div>                            <div id="f6c5a16d-d353-4cd5-93f9-5efac40cb129" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6c5a16d-d353-4cd5-93f9-5efac40cb129")) {                    Plotly.newPlot(                        "f6c5a16d-d353-4cd5-93f9-5efac40cb129",                        [{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.5024599151132952},"mode":"lines","x":[0.3306530236815577,0.3306530236815577,null],"y":[0.9699188417766131,0.9699188417766131,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.07334757979817395},"mode":"lines","x":[0.3306530236815577,-0.7162996655903722,null],"y":[0.9699188417766131,0.2751441018680414,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.17569954274901048},"mode":"lines","x":[0.3306530236815577,-0.012998393093148604,null],"y":[0.9699188417766131,0.48438784421286946,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.0251372260458406},"mode":"lines","x":[0.3306530236815577,0.809524870471631,null],"y":[0.9699188417766131,-0.5884412244632972,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.003405275555126829},"mode":"lines","x":[0.3306530236815577,-0.37165515352877226,null],"y":[0.9699188417766131,-1.0,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.09779077561165349},"mode":"lines","x":[0.3306530236815577,-0.19828404753398793,null],"y":[0.9699188417766131,0.008996763434670142,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.022379546535453314},"mode":"lines","x":[0.3306530236815577,0.15905936559309222,null],"y":[0.9699188417766131,-0.1500063268288975,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.18286773177000437},"mode":"lines","x":[-0.7162996655903722,-0.7162996655903722,null],"y":[0.2751441018680414,0.2751441018680414,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.15980125506740417},"mode":"lines","x":[-0.7162996655903722,-0.012998393093148604,null],"y":[0.2751441018680414,0.48438784421286946,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.0074475535780431845},"mode":"lines","x":[-0.7162996655903722,0.809524870471631,null],"y":[0.2751441018680414,-0.5884412244632972,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.049257734246344616},"mode":"lines","x":[-0.7162996655903722,-0.37165515352877226,null],"y":[0.2751441018680414,-1.0,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.11197530333066606},"mode":"lines","x":[-0.7162996655903722,-0.19828404753398793,null],"y":[0.2751441018680414,0.008996763434670142,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.15437135817339623},"mode":"lines","x":[-0.7162996655903722,0.15905936559309222,null],"y":[0.2751441018680414,-0.1500063268288975,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.4739185409380636},"mode":"lines","x":[-0.012998393093148604,-0.012998393093148604,null],"y":[0.48438784421286946,0.48438784421286946,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.02911452948342644},"mode":"lines","x":[-0.012998393093148604,0.809524870471631,null],"y":[0.48438784421286946,-0.5884412244632972,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.019330902508933212},"mode":"lines","x":[-0.012998393093148604,-0.37165515352877226,null],"y":[0.48438784421286946,-1.0,null],"type":"scatter"},{"hoverinfo":"none ...

# %%
interaction_data_long.head()
# Out:
#         Feature1 Feature2  Interaction
# 0           step     step     0.100492
# 3         amount     step     0.014670
# 5         amount   amount    -0.036574
# 6  oldbalanceOrg     step    -0.035140
# 8  oldbalanceOrg   amount     0.031960

# %%
import networkx as nx
import plotly.graph_objects as go
from community import community_louvain
import matplotlib.cm as cm
import numpy as np

def create_plotly_network_graph_fixed(interaction_data_long):
    G = nx.Graph()
    for _, row in interaction_data_long.iterrows():
        # Ensure positive weights for visualization
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    partition = community_louvain.best_partition(G)
    pos = nx.spring_layout(G)

    # Prepare edge trace
    edge_x = []
    edge_y = []
    edge_weight = []

    for edge in G.edges(data=True):
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        weight = edge[2]['weight']
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])
        edge_weight.append(weight)

    edge_trace = go.Scatter(x=edge_x, y=edge_y, line=dict(width=1, color='grey'), hoverinfo='none', mode='lines')

    # Prepare node trace
    node_x = []
    node_y = []
    node_text = []
    node_size = []
    community_colors = [cm.plasma(partition[node] / max(partition.values())) for node in G.nodes()]

    for node in G.nodes():
        x, y = pos[node]
        node_x.append(x)
        node_y.append(y)
        node_text.append(node)
        node_size.append(len(G[node]) * 10)  # Example for node size, adjust as needed

    node_trace = go.Scatter(x=node_x, y=node_y, mode='markers', text=node_text, hoverinfo='text',
                            marker=dict(showscale=True, colorscale='turbo', color=community_colors, size=node_size))

    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(title='Network Graph with Community Detection', showlegend=False, hovermode='closest',
                                     margin=dict(b=0, l=0, r=0, t=0),
                                     xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                                     yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

    return fig

# %%
pipeline = rfc_pipeline
X_train =  X_train_smote    #X_train_smote  
live_df = live_df  
model_name = 'Random Forest'
technique_name = 'SHAP'

explainer = ModelExplainer(pipeline, live_df)
interaction_data_long = explainer.prepare_interaction_data_for_graph()

fig = create_plotly_network_graph_fixed(interaction_data_long)
fig.show()
# Out:
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:432: UserWarning:
#
# X has feature names, but RandomForestClassifier was fitted without feature names
# <div>                            <div id="56491a9f-cb1a-4845-9181-0f0decab27d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56491a9f-cb1a-4845-9181-0f0decab27d6")) {                    Plotly.newPlot(                        "56491a9f-cb1a-4845-9181-0f0decab27d6",                        [{"hoverinfo":"none","line":{"color":"grey","width":1},"mode":"lines","x":[0.9999999999999999,0.9999999999999999,null,0.9999999999999999,-0.7292351742675351,null,0.9999999999999999,-0.559283619985221,null,0.9999999999999999,-0.0388100124556796,null,0.9999999999999999,0.5701828227835479,null,0.9999999999999999,-0.045025965686092,null,0.9999999999999999,-0.19782805038902015,null,-0.7292351742675351,-0.7292351742675351,null,-0.7292351742675351,-0.559283619985221,null,-0.7292351742675351,-0.0388100124556796,null,-0.7292351742675351,0.5701828227835479,null,-0.7292351742675351,-0.045025965686092,null,-0.7292351742675351,-0.19782805038902015,null,-0.559283619985221,-0.559283619985221,null,-0.559283619985221,-0.0388100124556796,null,-0.559283619985221,0.5701828227835479,null,-0.559283619985221,-0.045025965686092,null,-0.559283619985221,-0.19782805038902015,null,-0.0388100124556796,-0.0388100124556796,null,-0.0388100124556796,0.5701828227835479,null,-0.0388100124556796,-0.045025965686092,null,-0.0388100124556796,-0.19782805038902015,null,0.5701828227835479,0.5701828227835479,null,0.5701828227835479,-0.045025965686092,null,0.5701828227835479,-0.19782805038902015,null,-0.045025965686092,-0.045025965686092,null,-0.045025965686092,-0.19782805038902015,null,-0.19782805038902015,-0.19782805038902015,null],"y":[0.6896860514668594,0.6896860514668594,null,0.6896860514668594,0.11157947238111543,null,0.6896860514668594,-0.4261854501448437,null,0.6896860514668594,0.5864885995766338,null,0.6896860514668594,-0.4451081332838897,null,0.6896860514668594,-0.44950408443620665,null,0.6896860514668594,-0.06695645555966821,null,0.11157947238111543,0.11157947238111543,null,0.11157947238111543,-0.4261854501448437,null,0.11157947238111543,0.5864885995766338,null,0.11157947238111543,-0.4451081332838897,null,0.11157947238111543,-0.44950408443620665,null,0.11157947238111543,-0.06695645555966821,null,-0.4261854501448437,-0.4261854501448437,null,-0.4261854501448437,0.5864885995766338,null,-0.4261854501448437,-0.4451081332838897,null,-0.4261854501448437,-0.44950408443620665,null,-0.4261854501448437,-0.06695645555966821,null,0.5864885995766338,0.5864885995766338,null,0.5864885995766338,-0.4451081332838897,null,0.5864885995766338,-0.44950408443620665,null,0.5864885995766338,-0.06695645555966821,null,-0.4451081332838897,-0.4451081332838897,null,-0.4451081332838897,-0.44950408443620665,null,-0.4451081332838897,-0.06695645555966821,null,-0.44950408443620665,-0.44950408443620665,null,-0.44950408443620665,-0.06695645555966821,null,-0.06695645555966821,-0.06695645555966821,null],"type":"scatter"},{"hoverinfo":"text","marker":{"color":[[0.050383,0.029803,0.527975,1.0],[0.798216,0.280197,0.469538,1.0],[0.798216,0.280197,0.469538,1.0],[0.940015,0.975158,0.131326,1.0],[0.940015,0.975158,0.131326,1.0],[0.494877,0.01199,0.657865,1.0],[0.973416,0.585761,0.25154,1.0]],"colorscale":[[0.0,"#30123b"],[0.07142857142857142,"#4145ab"],[0.14285714285714285,"#4675ed"],[0.21428571428571427,"#39a2fc"],[0.2857142857142857,"#1bcfd4"],[0.35714285714285715,"#24eca6"],[0.42857142857142855,"#61fc6c"],[0.5,"#a4fc3b"],[0.5714285714285714,"#d1e834"],[0.6428571428571429,"#f3c63a"],[0.7142857142857143,"#fe9b2d"],[0.7857142857142857,"#f36315"],[0.8571428571428571,"#d93806"],[0.9285714285714286,"#b11901"],[1.0,"#7a0402"]],"showscale":true,"size":[70,70,70,70,70,70,70]},"mode":"markers","text":["step","amount","oldbalanceOrg","bal_chg","orig_zero","amt_bal_ratio","chg_amt_ratio"],"x":[ ...

# %%
import networkx as nx
import plotly.graph_objects as go
from community import community_louvain
import matplotlib.cm as cm
import numpy as np

def create_plotly_network_graph_corrected(interaction_data_long):
    G = nx.Graph()

    for _, row in interaction_data_long.iterrows():
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    partition = community_louvain.best_partition(G)
    pos = nx.spring_layout(G)

    edge_trace = []
    for edge in G.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        weight = G[edge[0]][edge[1]]['weight']
        edge_trace.append(go.Scatter(x=[x0, x1, None], y=[y0, y1, None],
                                     mode='lines',
                                     line=dict(width=2, color='grey'), # Simplify by using a uniform color and width
                                     hoverinfo='none'))

    node_trace = go.Scatter(x=[], y=[], text=[], mode='markers', hoverinfo='text',
                            marker=dict(showscale=True, colorscale='YlGnBu',
                                        color=[], size=[], line=dict(width=2, color='black')))

    for node in G.nodes():
        x, y = pos[node]
        node_trace['x'] += (x,)
        node_trace['y'] += (y,)
        # Setting node size based on degree for simplification
        node_trace['marker']['color'] += (len(G[node]),)  # Use node degree as color
        node_trace['marker']['size'] += (10 * len(G[node]),)  # Adjust node size based on degree
        node_trace['text'] += (node,)

    fig = go.Figure(data=edge_trace + [node_trace],
                    layout=go.Layout(showlegend=False, hovermode='closest',
                                     margin={'b': 0, 'l': 0, 'r': 0, 't': 0},
                                     xaxis={'showgrid': False, 'zeroline': False, 'showticklabels': False},
                                     yaxis={'showgrid': False, 'zeroline': False, 'showticklabels': False}))

    return fig

# %%
fig = create_plotly_network_graph_corrected(interaction_data_long)
fig.show()
# Out:
# <div>                            <div id="c270cbb3-b36b-4a98-92b8-79626acffe23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c270cbb3-b36b-4a98-92b8-79626acffe23")) {                    Plotly.newPlot(                        "c270cbb3-b36b-4a98-92b8-79626acffe23",                        [{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[1.0,1.0,null],"y":[-0.04755577819249051,-0.04755577819249051,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[1.0,-0.6730132548930785,null],"y":[-0.04755577819249051,0.019759081925047134,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[1.0,-0.3473009714813943,null],"y":[-0.04755577819249051,0.13720387894776057,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[1.0,0.21952883887090177,null],"y":[-0.04755577819249051,-0.41365939845273003,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[1.0,0.05743343996972061,null],"y":[-0.04755577819249051,0.5094898370787296,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[1.0,-0.18610317399649004,null],"y":[-0.04755577819249051,-0.23057973721833855,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[1.0,-0.07054487846965964,null],"y":[-0.04755577819249051,0.025342115912021793,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[-0.6730132548930785,-0.6730132548930785,null],"y":[0.019759081925047134,0.019759081925047134,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[-0.6730132548930785,-0.3473009714813943,null],"y":[0.019759081925047134,0.13720387894776057,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[-0.6730132548930785,0.21952883887090177,null],"y":[0.019759081925047134,-0.41365939845273003,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[-0.6730132548930785,0.05743343996972061,null],"y":[0.019759081925047134,0.5094898370787296,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[-0.6730132548930785,-0.18610317399649004,null],"y":[0.019759081925047134,-0.23057973721833855,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[-0.6730132548930785,-0.07054487846965964,null],"y":[0.019759081925047134,0.025342115912021793,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[-0.3473009714813943,-0.3473009714813943,null],"y":[0.13720387894776057,0.13720387894776057,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[-0.3473009714813943,0.21952883887090177,null],"y":[0.13720387894776057,-0.41365939845273003,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[-0.3473009714813943,0.05743343996972061,null],"y":[0.13720387894776057,0.5094898370787296,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[-0.3473009714813943,-0.18610317399649004,null],"y":[0.13720387894776057,-0.23057973721833855,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[-0.3473009714813943,-0.07054487846965964,null],"y":[0.13720387894776057,0.025342115912021793,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"grey","width":2},"mode":"lines","x":[0.21952883887090177,0.21952883887090177,null],"y":[-0.41365939845273003,-0.41365939845273003, ...

# %%
import networkx as nx
import plotly.graph_objects as go
from community import community_louvain
import matplotlib.cm as cm
import matplotlib.pyplot as plt

def create_plotly_network_graph10(interaction_data_long):
    G = nx.Graph()

    # Add edges to the graph with interaction strength as weight
    for _, row in interaction_data_long.iterrows():
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    # Community detection to determine node color
    partition = community_louvain.best_partition(G)
    pos = nx.spring_layout(G)  # Node position layout

    # Edge Traces
    edge_trace = []
    for edge in G.edges(data=True):
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        weight = edge[2]['weight']
        
        # Edge width based on weight, adjust scaling factor as needed
        edge_width = weight * 10

        edge_trace.append(go.Scatter(x=[x0, x1, None], y=[y0, y1, None],
                                     line=dict(width=edge_width, color='rgba(75,75,75,1)'),
                                     hoverinfo='none', mode='lines'))

    # Node Trace
    node_trace = go.Scatter(x=[], y=[], text=[], mode='markers', hoverinfo='text',
                            marker=dict(showscale=True, colorscale='turbo',
                                        color=[],
                                        size=[],
                                        colorbar=dict(title="Community")))

    # Add node positions, colors based on community, and sizes based on degree
    for node in G.nodes():
        x, y = pos[node]
        node_trace['x'] += tuple([x])
        node_trace['y'] += tuple([y])
        node_trace['marker']['color'] += tuple([partition[node]])
        node_trace['marker']['size'] += tuple([len(G[node]) * 5])  # Node size based on degree
        node_trace['text'] += tuple([f'{node}'])

    fig = go.Figure(data=edge_trace + [node_trace],
                    layout=go.Layout(title='Network Graph with Community Detection',
                                     showlegend=False,
                                     hovermode='closest',
                                     xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                                     yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

    return fig

# %%
fig = create_plotly_network_graph10(interaction_data_long)
fig.show()
# Out:
# <div>                            <div id="c84b24ef-593a-480c-944b-523137bf2e47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
.30874271634679246},"mode":"lines","x":[-0.5281396201008046,0.1175379134996732,null],"y":[-0.5512670011183554,0.23049683429757908,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.9478370818761273},"mode":"lines","x":[0.29445677085216826,0.29445677085216826,null],"y":[-0.36136181872688394,-0.36136181872688394,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.05822905896685288},"mode":"lines","x":[0.29445677085216826,0.6003950973479486,null],"y":[-0.36136181872688394,0.8719701978939405,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.038661805017866424},"mode":"lines","x":[0.29445677085216826,-0.7016521830248724,null],"y":[-0.36136181872688394,0.8595033476990641 ...

# %%
import networkx as nx
import plotly.graph_objects as go
from community import community_louvain
import matplotlib.pyplot as plt

def create_network_graph11(interaction_data_long):
    # Initialize graph
    G = nx.Graph()

    # Add edges and nodes to the graph
    for _, row in interaction_data_long.iterrows():
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    # Community detection
    partition = community_louvain.best_partition(G)
    pos = nx.spring_layout(G)  # Position nodes in layout

    # Edge trace
    edge_trace = go.Scatter(x=[], y=[], line=dict(width=0.5, color='#888'), hoverinfo='none', mode='lines')

    # Add edges to edge_trace
    for edge in G.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_trace['x'] += (x0, x1, None)
        edge_trace['y'] += (y0, y1, None)

    # Node trace
    node_trace = go.Scatter(x=[], y=[], text=[], mode='markers', hoverinfo='text',
                            marker=dict(showscale=True, colorscale='YlGnBu', color=[], size=10, colorbar=dict(title='Interaction Strength')))

    # Add nodes to node_trace
    for node in G.nodes():
        x, y = pos[node]
        node_trace['x'] += (x,)
        node_trace['y'] += (y,)
        # Color node based on its partition (community)
        color = partition[node]
        node_trace['marker']['color'] += (color,)
        node_info = f"{node}"  # Node hover text
        node_trace['text'] += (node_info,)

    # Create figure
    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(title='Network Graph with Community Detection',
                                     titlefont_size=16, showlegend=False,
                                     hovermode='closest',
                                     margin=dict(b=0, l=0, r=0, t=40),
                                     annotations=[dict(text="Python network graph made with Plotly", showarrow=False,
                                                      xref="paper", yref="paper", x=0.005, y=-0.002)],
                                     xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                                     yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

    return fig

# %%
fig = create_network_graph11(interaction_data_long)
fig.show()
# Out:
# <div>                            <div id="e5d0c98e-543d-4442-9f51-6fc101238180" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
# %%
import networkx as nx
import plotly.graph_objects as go
from community import community_louvain
import matplotlib.cm as cm
import numpy as np

def create_network_graph_updated_1(interaction_data_long):
    G = nx.Graph()

    # Add edges with interaction values as weights
    for _, row in interaction_data_long.iterrows():
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    # Community detection for node coloring
    partition = community_louvain.best_partition(G)
    pos = nx.spring_layout(G)

    # Node attributes for size and label
    node_attr = {node: {'size': 0, 'label': node} for node in G.nodes()}
    for node in G.nodes():
        node_attr[node]['size'] = len(G[node]) * 10  # Example size, adjust as needed

    # Calculate color for each node based on its community
    community_colors = {node: partition[node] for node in G.nodes()}
    max_community = max(community_colors.values())
    node_color = [community_colors[node] / max_community for node in G.nodes()]

    # Edge trace
    edge_x = []
    edge_y = []
    for edge in G.edges():
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])

    edge_trace = go.Scatter(x=edge_x, y=edge_y, line=dict(width=0.5, color='#888'), hoverinfo='none', mode='lines')

    # Node trace
    node_x = [pos[node][0] for node in G.nodes()]
    node_y = [pos[node][1] for node in G.nodes()]
    node_size = [node_attr[node]['size'] for node in G.nodes()]
    node_text = [node_attr[node]['label'] for node in G.nodes()]

    node_trace = go.Scatter(x=node_x, y=node_y, mode='markers', hoverinfo='text', text=node_text,
                            marker=dict(showscale=True, colorscale='YlGnBu', color=node_color, size=node_size,
                                        colorbar=dict(title='Community')))

    fig = go.Figure(data=[edge_trace, node_trace],
                    layout=go.Layout(title='Network Graph with Community Detection',
                                     showlegend=False, hovermode='closest',
                                     margin=dict(b=0, l=0, r=0, t=0),
                                     xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                                     yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

    return fig

# Example usage
# interaction_data_long = <your_dataframe>
# fig = create_network_graph_updated(interaction_data_long)
# fig.show()

# %%
fig = create_network_graph_updated_1(interaction_data_long)
fig.show()
# Out:
# <div>                            <div id="b60ed9fc-c80c-4ad5-9ea8-390668cd0084" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b60ed9fc-c80c-4ad5-9ea8-390668cd0084")) {                    Plotly.newPlot(                        "b60ed9fc-c80c-4ad5-9ea8-390668cd0084",                        [{"hoverinfo":"none","line":{"color":"#888","width":0.5},"mode":"lines","x":[0.68498966300964,0.68498966300964,null,0.68498966300964,0.32613552793133455,null,0.68498966300964,-0.11597021565965443,null,0.68498966300964,-0.6845925148930114,null,0.68498966300964,-0.30682301246751587,null,0.68498966300964,-0.054482256710976,null,0.68498966300964,0.15074280879018317,null,0.32613552793133455,0.32613552793133455,null,0.32613552793133455,-0.11597021565965443,null,0.32613552793133455,-0.6845925148930114,null,0.32613552793133455,-0.30682301246751587,null,0.32613552793133455,-0.054482256710976,null,0.32
# 6   oldbalanceOrg           step     0.002877
# 8   oldbalanceOrg         amount     0.042320
# 9   oldbalanceOrg  oldbalanceOrg     0.075649
# 10        bal_chg           step     0.000745
# 12        bal_chg         amount     0.005237
# 13        bal_chg  oldbalanceOrg     0.013214
# 14        bal_chg        bal_chg    -0.048272
# 15      orig_zero           step     0.000985
# 17      orig_zero         amount     0.010337
# 18      orig_zero  oldbalanceOrg     0.009070
# 19      orig_zero        bal_chg     0.010142
# 20      orig_zero      orig_zero     0.020475
# 21  amt_bal_ratio           step     0.007809
# 23  amt_bal_ratio         amount     0.022276
# 24  amt_bal_ratio  oldbalanceOrg     0.061259
# 25  amt_bal_ratio        bal_chg     0.011017
# 26  amt_bal_ratio      orig_zero     0.013274
# 27  amt_bal_ratio  amt_bal_ratio    -0.380562
# 28  chg_amt_ratio           step    -0.001157
# 30  chg_amt_ratio         amount     0.032536
# 31  chg_amt_ratio  oldbalanceOrg     0.067069
# 32  chg_amt_ratio        bal_chg     0.019833
# 33  chg_amt_ratio      orig_zero     0.012795
# 34  chg_amt_ratio  amt_bal_ratio     0.100549
# 35  chg_amt_ratio  chg_amt_ratio    -0.215940

# %%
import networkx as nx
import plotly.graph_objects as go
from community import community_louvain
import matplotlib.cm as cm
import numpy as np

def create_plotly_network_graph_interaction_strength(interaction_data_long):
    G = nx.Graph()

    # Add edges to the graph with interaction strength as weight
    for _, row in interaction_data_long.iterrows():
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    pos = nx.spring_layout(G)  # Node position layout

    # Calculate interaction strength for each node
    node_strength = {node: np.sum([data['weight'] for _, _, data in G.edges(node, data=True)]) for node in G.nodes()}
    # Normalize the strengths for color mapping
    min_strength, max_strength = min(node_strength.values()), max(node_strength.values())
    strength_norm = {node: (strength - min_strength) / (max_strength - min_strength) for node, strength in node_strength.items()}

    # Edge Traces
    edge_trace = []
    for edge in G.edges(data=True):
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        weight = edge[2]['weight']
        
        edge_width = weight * 7  # Edge width based on weight, adjust scaling factor as needed
        edge_trace.append(go.Scatter(x=[x0, x1, None], y=[y0, y1, None],
                                     line=dict(width=edge_width, color='rgba(75,75,75,1)'),
                                     hoverinfo='none', mode='lines'))

    # Node Trace
    node_trace = go.Scatter(x=[], y=[], text=[], mode='markers+text', hoverinfo='text',
                            marker=dict(showscale=True, colorscale='turbo',
                                        color=[strength_norm[node] for node in G.nodes()],
                                        size=[len(G[node]) * 8 for node in G.nodes()],  # Node size based on degree
                                        colorbar=dict(title="Interaction Strength")))

    # Add node positions to the trace
    for node in G.nodes():
        x, y = pos[node]
        node_trace['x'] += tuple([x])
        node_trace['y'] += tuple([y])
        node_trace['text'] += tuple([f'{node}'])

    fig = go.Figure(data=edge_trace + [node_trace],
                    layout=go.Layout(title='Network Graph with Interaction Strength',
                                     showlegend=False,
                                     hovermode='closest',
                                     height=700,  # Specify figure size
                                     width=1050,                                     
                                     xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                                     yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

    return fig

# %%
fig = create_plotly_network_graph_interaction_strength(interaction_data_long)
fig.show()
# Out:
# <div>                            <div id="d139e7e0-718d-4b01-ad8b-32b45702bd44" class="plotly-graph-div" style="height:700px; width:1050px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.36769487307799553},"mode":"lines","x":[-0.6675700143767336,-0.5762138606836044,null],"y":[0.5736117437218641,-0.057472203961836575,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.6613247301127825},"mode":"lines","x":[-0.2817846994616861,-0.2817846994616861,null],"y":[-0.6174237314510879,-0.6174237314510879,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.11095198814123908},"mode":"lines","x":[-0.2817846994616861,-0.008299152960201972,null],"y":[-0.6174237314510879,0.1366381666064378,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(75,75,75,1)","width":0.029480429499849407},"mode":"lines","x":[-0.2817846994616861,0.5632962627587279,null],"y":[-0.6174237314510879,-1.0,null],"type":"scatter"},{"hoverinfo":"none","line":{ ...

# %%
import networkx as nx
import plotly.graph_objects as go
from community import community_louvain
import matplotlib.cm as cm
import numpy as np

def create_plotly_network_graph_interaction_strength_1(interaction_data_long):
    G = nx.Graph()

    # Add edges to the graph with interaction strength as weight
    for _, row in interaction_data_long.iterrows():
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    pos = nx.spring_layout(G)  # Node position layout

    # Calculate interaction strength for each node
    node_strength = {node: np.sum([data['weight'] for _, _, data in G.edges(node, data=True)]) for node in G.nodes()}
    # Normalize the strengths for color mapping
    min_strength, max_strength = min(node_strength.values()), max(node_strength.values())
    strength_norm = {node: (strength - min_strength) / (max_strength - min_strength) for node, strength in node_strength.items()}

    # Edge Traces
    edge_trace = []
    for edge in G.edges(data=True):
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        weight = edge[2]['weight']
        
        edge_width = weight * 5  # Edge width based on weight, adjust scaling factor as needed
        edge_trace.append(go.Scatter(x=[x0, x1, None], y=[y0, y1, None],
                                     line=dict(width=edge_width, color='rgba(50,205,50,1)'),
                                     hoverinfo='none', mode='lines'))

    # Node Trace
    node_trace = go.Scatter(x=[], y=[], text=[], mode='markers+text', hoverinfo='text',
                            marker=dict(showscale=True, colorscale='turbo',
                                        color=[strength_norm[node] for node in G.nodes()],
                                        size=[len(G[node]) * 8 for node in G.nodes()],  # Node size based on degree
                                        colorbar=dict(title="Interaction Strength")))

    # Add node positions to the trace
    for node in G.nodes():
        x, y = pos[node]
        node_trace['x'] += tuple([x])
        node_trace['y'] += tuple([y])
        node_trace['text'] += tuple([f'{node}'])

    fig = go.Figure(data=edge_trace + [node_trace],
                    layout=go.Layout(title='Network Graph with Interaction Strength',
                                     showlegend=False,
                                     hovermode='closest',
                                     height=700,  # Specify figure size
                                     width=1050,                                     
                                     xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                                     yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                                     paper_bgcolor='rgba(0,0,0,0)',  # Transparent background
                                     plot_bgcolor='rgba(0,0,0,0)'))  # Transparent plot background

    return fig

# %%
fig = create_plotly_network_graph_interaction_strength_1(interaction_data_long)
fig.show()
# Out:
# <div>                            <div id="9134e047-98f8-4c8c-bd06-a6d137ba8d66" class="plotly-graph-div" style="height:700px; width:1050px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
50,205,50,1)","width":0.2626391950557111},"mode":"lines","x":[0.5964034070947354,0.01648847250074172,null],"y":[0.6249201201623699,0.33830075598278186,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(50,205,50,1)","width":0.47237480722341607},"mode":"lines","x":[-0.7604951928973802,-0.7604951928973802,null],"y":[-0.12440737975539905,-0.12440737975539905,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(50,205,50,1)","width":0.07925142010088507},"mode":"lines","x":[-0.7604951928973802,0.377853057638001,null],"y":[-0.12440737975539905,-0.12557472720025945,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(50,205,50,1)","width":0.021057449642749578},"mode":"lines","x":[-0.7604951928973802,0.6893425698742166,null],"y":[-0.12440737975539905,-0.9999999 ...

# %%
import networkx as nx
import plotly.graph_objects as go
from community import community_louvain
from matplotlib import patheffects, colors, cm
import matplotlib.cm as cm
import numpy as np

def network_graph_interaction_strength1(interaction_data_long):
    G = nx.Graph()

    # Add edges to the graph with interaction strength as weight
    for _, row in interaction_data_long.iterrows():
        G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

    pos = nx.spring_layout(G)  # Node position layout

    # Calculate interaction strength for each node
    node_strength = {node: np.sum([data['weight'] for _, _, data in G.edges(node, data=True)]) for node in G.nodes()}
    # Normalize the strengths for color mapping
    min_strength, max_strength = min(node_strength.values()), max(node_strength.values())
    strength_norm = {node: (strength - min_strength) / (max_strength - min_strength) for node, strength in node_strength.items()}

    # Edge Traces
    edge_trace = []
    for edge in G.edges(data=True):
        x0, y0 = pos[edge[0]]
        x1, y1 = pos[edge[1]]
        weight = edge[2]['weight']
        
        edge_width = weight * 12  # Edge width based on weight, adjust scaling factor as needed
        edge_trace.append(go.Scatter(x=[x0, x1, None], y=[y0, y1, None],
                                     line=dict(width=edge_width, color='rgba(0,0,0,1)'),
                                     hoverinfo='none', mode='lines'))

    # Node Trace
    node_trace = go.Scatter(x=[], y=[], text=[], mode='markers+text', hoverinfo='text',
                            marker=dict(showscale=True, colorscale='plasma',
                                        color=[strength_norm[node] for node in G.nodes()],
                                        size=[len(G[node]) * 6 for node in G.nodes()],  # Node size based on degree
                                        #colorbar=dict(title="Interaction Strength")))
                                        colorbar=dict(thickness=15, title='Interaction Strength', xanchor='left', titleside='right')))

    
  

    # Add node positions to the trace
    for node in G.nodes():
        x, y = pos[node]
        node_trace['x'] += tuple([x])
        node_trace['y'] += tuple([y])
        node_trace['text'] += tuple([f'{node}'])

    fig = go.Figure(data=edge_trace + [node_trace],
                    layout=go.Layout(title='Features Interactions  with Network Graph',
                                     showlegend=False,
                                     hovermode='closest',
                                     height=700,  # Specify figure size
                                     width=1000,                                     
                                     xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                                     yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))
#                                      paper_bgcolor='rgba(0,0,0,0)',  # Transparent background
#                                      plot_bgcolor='rgba(0,0,0,0)'))  # Transparent plot background

    return fig

# %%
fig = network_graph_interaction_strength(interaction_data_long)
fig.show()
# Out:
# <div>                            <div id="a519c84f-de4f-45bd-863e-25eac0c40da4" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
},"mode":"lines","x":[0.0023436500671403055,-0.18824191114110314,null],"y":[0.7408158105022925,0.22646483450742128,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,0,1)","width":1.1336995373361987},"mode":"lines","x":[-0.391520734160238,-0.391520734160238,null],"y":[-0.518715022314251,-0.518715022314251,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,0,1)","width":0.19020340824212414},"mode":"lines","x":[-0.391520734160238,0.3099965661968536,null],"y":[-0.518715022314251,0.1540486226320979,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,0,1)","width":0.05053787914259898},"mode":"lines","x":[-0.391520734160238,1.0,null],"y":[-0.518715022314251,-0.24543156087253323,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,0,1)"," ...

# %%
pipeline = gbc_pipeline
X_train =  X_train_smote    
live_df = live_df  
model_name = 'Gradient Forest'
technique_name = 'SHAP'

explainer = ModelExplainer(pipeline, live_df)
interaction_data_long_gbc = explainer.prepare_interaction_data_for_graph_gbc()
interaction_data_long_gbc
# Out:
# C:\Users\Administrator\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:432: UserWarning:
#
# X has feature names, but GradientBoostingClassifier was fitted without feature names
#          Feature1       Feature2  Interaction
# 0            step           step    -0.037854
# 3          amount           step    -0.006179
# 5          amount         amount     0.051872
# 6   oldbalanceOrg           step    -0.000658
# 8   oldbalanceOrg         amount    -0.000064
# 9   oldbalanceOrg  oldbalanceOrg    -0.481524
# 10        bal_chg           step    -0.000056
# 12        bal_chg         amount    -0.000057
# 13        bal_chg  oldbalanceOrg    -0.000096
# 14        bal_chg        bal_chg     0.003859
# 21  amt_bal_ratio           step    -0.003203
# 23  amt_bal_ratio         amount    -0.069446
# 24  amt_bal_ratio  oldbalanceOrg     0.185723
# 25  amt_bal_ratio        bal_chg     0.000423
# 27  amt_bal_ratio  amt_bal_ratio    -2.080096
# 28  chg_amt_ratio           step    -0.016438
# 30  chg_amt_ratio         amount     0.012098
# 31  chg_amt_ratio  oldbalanceOrg    -0.092032
# 32  chg_amt_ratio        bal_chg    -0.000894
# 34  chg_amt_ratio  amt_bal_ratio    -0.526414
# 35  chg_amt_ratio  chg_amt_ratio    -6.556300

# %%
network_graph_gbc = network_graph_interaction_strength(interaction_data_long_gbc)
network_graph_gbc.show()
# Out:
# <div>                            <div id="b1c253c8-630b-4906-bc43-b039ee3e3ddf" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1c253c8-630b-4906-bc43-b039ee3e3ddf")) {                    Plotly.newPlot(                        "b1c253c8-630b-4906-bc43-b039ee3e3ddf",                        [{"hoverinfo":"none","line":{"color":"rgba(0,0,0,1)","width":0.4542427782588824},"mode":"lines","x":[0.729718261828253,0.729718261828253,null],"y":[-0.3332653202606139,-0.3332653202606139,null],"type":"scatter"},{"hoverinfo":"none","line":{"color":"rgba(0,0,0,1)","width":0.07414920813018924},"mode":"lines","x":[0.729718261828253,0.21393684920249764,
# %%
def analyze_model_interactions1(model_name, technique_name, interaction_data_long, interaction_data_long_gbc):
    
       
    if model_name == "Random Forest" and technique_name == "SHAP":
        network_graph = create_plotly_network_graph_interaction_strength_2(interaction_data_long)
#             top_main_effect, top_interaction = explainer.features_interaction()
    elif model_name == "Gradient Boost" and technique_name == "SHAP":
        network_graph = create_plotly_network_graph_interaction_strength_2(interaction_data_long_gbc)
#             top_main_effect, top_interaction = explainer.features_interaction_gbc()
    else:
        return None

    return network_graph

# %%
pipeline = gbc_pipeline
X_train =  X_train_smote    
live_df = live_df  
model_name = 'Gradient Forest'
technique_name = 'SHAP'

explainer = ModelExplainer(pipeline, live_df)
network_graph_gbc = explainer.network_graph_interaction_strength()
network_graph_gbc.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[421], line 8
#       5 technique_name = 'SHAP'
#       7 explainer = ModelExplainer(pipeline, live_df)
# ----> 8 network_graph_gbc = explainer.network_graph_interaction_strength()
#       9 network_graph_gbc.show()
#
# AttributeError: 'ModelExplainer' object has no attribute 'network_graph_interaction_strength'

# %%
    def network_graph_interaction_strength(interaction_data_long):
        G = nx.Graph()

        # Add edges to the graph with interaction strength as weight
        for _, row in interaction_data_long.iterrows():
            G.add_edge(row['Feature1'], row['Feature2'], weight=abs(row['Interaction']))

        pos = nx.spring_layout(G)

        # Calculate interaction strength for each node
        node_strength = {node: np.sum([data['weight'] for _, _, data in G.edges(node, data=True)]) for node in G.nodes()}
        # Normalize the strengths for color mapping
        min_strength, max_strength = min(node_strength.values()), max(node_strength.values())
        strength_norm = {node: (strength - min_strength) / (max_strength - min_strength) for node, strength in node_strength.items()}

        # Edge Traces
        edge_trace = []
        for edge in G.edges(data=True):
            x0, y0 = pos[edge[0]]
            x1, y1 = pos[edge[1]]
            weight = edge[2]['weight']

            edge_width = weight * 12  # Edge width based on weight
            edge_trace.append(go.Scatter(x=[x0, x1, None], y=[y0, y1, None],
                                         line=dict(width=edge_width, color='rgba(0,0,0,1)'),
                                         hoverinfo='none', mode='lines'))

        # Node Trace
        node_trace = go.Scatter(x=[], y=[], text=[], mode='markers+text', hoverinfo='text',
                                marker=dict(showscale=True, colorscale='plasma',
                                            color=[strength_norm[node] for node in G.nodes()],
                                            size=[len(G[node]) * 6 for node in G.nodes()],  
                                            colorbar=dict(thickness=15, title='Interaction Strength', xanchor='left', 
                                                          titleside='right')))




        # Add node positions to the trace
        for node in G.nodes():
            x, y = pos[node]
            node_trace['x'] += tuple([x])
            node_trace['y'] += tuple([y])
            node_trace['text'] += tuple([f'{node}'])

        fig = go.Figure(data=edge_trace + [node_trace],
                        layout=go.Layout(title='Features Interactions  with Network Graph',
                                         showlegend=False,
                                         hovermode='closest',
                                         height=700,  # Specify figure size
                                         width=1000,                                     
                                         xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                                         yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

        return fig
